# %%
# Importamos Librerias
import pandas as pd
import seaborn as sns

# %%
# Importamos el Dataset Titanic desde Seaborn
df = sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_pp1 = df.dropna()
df_pp1.reset_index(drop=True)

# %%
df_pp1

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[(df["age"] > 70) & (df["sex"] == "male")]
# Out:
#      survived  pclass   sex  age  sibsp  parch     fare embarked  class  who  \
# 96          0       1  male   71      0      0  34.6542        C  First  man
# 493         0       1  male   71      0      0  49.5042        C  First  man
# 630         1       1  male   80      0      0  30.0000        S  First  man
# 851         0       3  male   74      0      0   7.7750        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 96         True    A    Cherbourg    no   True
# 493        True  NaN    Cherbourg    no   True
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True

# %%
df[(df["sex"] == "male") & (df["age"] == 22)]
# Out:
#      survived  pclass   sex   age  sibsp  parch      fare embarked  class  \
# 0           0       3  male  22.0      1      0    7.2500        S  Third
# 60          0       3  male  22.0      0      0    7.2292        C  Third
# 80          0       3  male  22.0      0      0    9.0000        S  Third
# 112         0       3  male  22.0      0      0    8.0500        S  Third
# 212         0       3  male  22.0      0      0    7.2500        S  Third
# 225         0       3  male  22.0      0      0    9.3500        S  Third
# 243         0       3  male  22.0      0      0    7.1250        S  Third
# 287         0       3  male  22.0      0      0    7.8958        S  Third
# 320         0       3  male  22.0      0      0    7.2500        S  Third
# 373         0       1  male  22.0      0      0  135.6333        C  First
# 395         0       3  male  22.0      0      0    7.7958        S  Third
# 478         0       3  male  22.0      0      0    7.5208        S  Third
# ...

# %%
df.query('sex == "male" and age == 22 and fare > 8')
# Out:
#      survived  pclass   sex  age  sibsp  parch      fare embarked  class  who  \
# 80          0       3  male   22      0      0    9.0000        S  Third  man
# 112         0       3  male   22      0      0    8.0500        S  Third  man
# 225         0       3  male   22      0      0    9.3500        S  Third  man
# 373         0       1  male   22      0      0  135.6333        C  First  man
# 588         0       3  male   22      0      0    8.0500        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 80         True  NaN  Southampton    no   True
# 112        True  NaN  Southampton    no   True
# 225        True  NaN  Southampton    no   True
# 373        True  NaN    Cherbourg    no   True
# 588        True  NaN  Southampton    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
df["age"]=df["age"].fillna(df["age"].mean())

# %%
df["age"]=df["age"].astype(int)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age               int64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object
